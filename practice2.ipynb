# %%
import pandas as pd

# %%
df=pd.read_csv("HousePricePrediction.csv")
df1=df.dropna()
# df.head(20)

# %%
x=df1.drop(columns= ["MSZoning", "LotConfig", "BldgType", "Exterior1st","SalePrice"])

# %%
x
# Out:
#         Id  MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  \
# 0        0          60     8450            5       2003          2003
# 1        1          20     9600            8       1976          1976
# 2        2          60    11250            5       2001          2002
# 3        3          70     9550            5       1915          1970
# 4        4          60    14260            5       2000          2000
# ...    ...         ...      ...          ...        ...           ...
# 1455  1455          60     7917            5       1999          2000
# 1456  1456          20    13175            6       1978          1988
# 1457  1457          70     9042            9       1941          2006
# 1458  1458          20     9717            6       1950          1996
# 1459  1459          20     9937            6       1965          1965
#
#       BsmtFinSF2  TotalBsmtSF
# 0            0.0        856.0
# 1            0.0       1262.0
# 2            0.0        920.0
# ...

# %%
y=df1["SalePrice"]
y
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Name: SalePrice, Length: 1460, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.2, random_state=42
)

# %%
y_train.head()
# Out:
# 254     145000.0
# 1066    178000.0
# 638      85000.0
# 799     175000.0
# 380     127000.0
# Name: SalePrice, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([202557.9374021 , 233620.62893383, 120051.98714356, 134040.35280726,
#        263271.0227539 , 127449.81819673, 186181.16276496, 157753.60118982,
#        124602.09639799, 142621.77848951, 113476.10189918, 151218.99523931,
#        115932.44986158, 247003.18467406, 197295.80982231, 190478.30449889,
#        196683.48422666, 189193.45185039, 110146.07255011, 241062.78321246,
#        170374.88570578, 198356.31967826, 191416.91209722, 173206.38788033,
#        231725.43526673, 209131.11365407, 236915.33921068, 130252.93645157,
#        196582.04197476, 237159.60189715, 117687.6123255 , 210615.52014226,
#        215265.79562956, 143187.59054908, 261730.16884636, 165664.64614092,
#        157704.00844856, 196667.88814434, 235795.62958066,  66883.8650627 ,
#        107833.51848756, 197559.17116438, 150116.43011055, 295281.68156324,
#        144092.2503778 ,  83683.07461516, 128169.53782967, 157409.64575552,
# ...

# %%
y_test
# Out:
# 892     154500.0
# 1105    325000.0
# 413     115000.0
# 522     159000.0
# 1036    315500.0
#           ...
# 479      89471.0
# 1361    260000.0
# 802     189000.0
# 651     108000.0
# 722     124500.0
# Name: SalePrice, Length: 292, dtype: float64

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test, y_pred)
print("r-squared:",r2)

# adjusted r_squared
n=x_test.shape[0]
p=x_test.shape[1]

adjusted_r2 = 1-((1-r2)*(n-1)/(n-p-1))
print(adjusted_r2)
# Out:
# r-squared: 0.5749178852345282
# 0.5629014296934549

# %%
# Encoding
X=df1.drop(columns=["SalePrice","Exterior1st"])
Y=df1["SalePrice"]
X["House_age"] = 2026-X["YearBuilt"]
X["remod_age"]=2026-X["YearRemodAdd"]
X["Quality_area"] = X["OverallCond"]*X["LotArea"]
X["house_condn"] =  X["OverallCond"]*X["House_age"]
X=pd.get_dummies(X,columns=["LotConfig","MSZoning","BldgType"],drop_first=True,dtype=int)
X.sample(10)
# Out:
#         Id  MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  \
# 1268  1268          50    14100            9       1935          1997
# 1105  1105          60    12256            5       1994          1995
# 951    951          20     7800            5       1965          1965
# 180    180         160     2117            5       2000          2000
# 573    573          80     9967            5       2000          2000
# 769    769          60    53504            5       2003          2003
# 566    566          60    11198            5       2005          2007
# 1116  1116          80     7750            5       2002          2002
# 238    238          20    12030            5       2007          2007
# 312    312         190     7800            7       1939          1950
#
#       BsmtFinSF2  TotalBsmtSF  House_age  remod_age  ...  LotConfig_FR3  \
# 1268         0.0        728.0         91         29  ...              0
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size = 0.2, random_state=42
)
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
srs=pd.Series(Y_pred)
srs.head()
# Out:
# 0    168229.083649
# 1    258908.735198
# 2    111112.998168
# 3    139140.753134
# 4    257580.456482
# dtype: float64

# %%
srs1=pd.Series(Y_test)
srs1.head()
# Out:
# 892     154500.0
# 1105    325000.0
# 413     115000.0
# 522     159000.0
# 1036    315500.0
# Name: SalePrice, dtype: float64

# %%
from sklearn.metrics import r2_score
r2=r2_score(Y_test, Y_pred)
print("r-squared:",r2)
y_train_pred = model.predict(X_train)
r2_train=r2_score(Y_train,y_train_pred)
print("R2_train",r2_train)
# adjusted r_squared
n=X_test.shape[0]
p=X_test.shape[1]

adjusted_r2 = 1-((1-r2)*(n-1)/(n-p-1))
print(adjusted_r2)
# Out:
# r-squared: 0.6276561057451815
# R2_train 0.6074128667956897
# 0.5941869916548608
